# %%
import pandas as pd
import numpy as np

# %%
ds = pd.read_csv("advertising.csv")
ds.head(3)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
ds.describe()
ds.shape
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.regplot(x='TV', y = 'Sales', data=ds)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.pairplot(ds, x_vars=["TV", "Radio", "Newspaper"], y_vars="Sales", size=5, aspect=1, kind="scatter")

# %%
ds.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
sns.heatmap(ds.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
import statsmodels
import statsmodels.api as sm
import sklearn
from sklearn.model_selection import train_test_split

# %%
ds.head()
# create x and y
# create tranig and test set
# train your model with the train test
# evaluate on the train set
# evaluate on the test set
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
X = ds["TV"]
y = ds["Sales"]

# %%
#help(train_test_split)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state = 100)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (140,)
# (140,)
# (60,)
# (60,)

# %%
X_train_sm = sm.add_constant(X_train)
#help(sm.OLS)
lr = sm.OLS(y_train, X_train_sm)
lr_model = lr.fit()
lr_model.params
# Out:
# const    6.948683
# TV       0.054546
# dtype: float64

# %%
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     611.2
# Date:                Sat, 13 May 2023   Prob (F-statistic):           1.52e-52
# Time:                        08:22:00   Log-Likelihood:                -321.12
# No. Observations:                 140   AIC:                             646.2
# Df Residuals:                     138   BIC:                             652.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.9487      0.385     18.068      0.000       6.188       7.709
# ...

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, (6.948683 + X_train*0.054546), 'r' )
plt.show()

# %%
#y_train, y_train_pred
#y_train_pred = 6.948683 + X_train*0.054546
y_train_pred = lr_model.predict(X_train_sm)
res = y_train - y_train_pred

# %%
sns.distplot(res)
# Out:
# <Axes: ylabel='Density'>

# %%
plt.scatter(X_train, res)

# %%
y_test_pred = lr_model.predict(sm.add_constant(X_test))
res_test = y_test - y_test_pred

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_test_pred, 'r')
plt.show()

# %%
sns.distplot(res_test)
# Out:
# <Axes: ylabel='Density'>

# %%
plt.scatter(X_test, res_test)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
#help(mean_squared_error)

# %%
print(mean_squared_error(y_true=y_train, y_pred=y_train_pred))
print(mean_squared_error(y_true=y_test, y_pred=y_test_pred))
# Out:
# 5.752400386486835
# 4.077556371826956

# %%
print(r2_score(y_true=y_train, y_pred=y_train_pred))
print(r2_score(y_true=y_test, y_pred=y_test_pred))
# Out:
# 0.8157933136480389
# 0.7921031601245658

# %%
#Linear regression using sklearn

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 100, train_size=0.7)

# %%
X_train_lm = X_train.values.reshape(-1,1)
y_train_lm = y_train.values.reshape(-1,1)
print(X_train.shape, " => ", X_train_lm.shape)
# Out:
# (140,)  =>  (140, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm.fit(X_train_lm, y_train_lm)
# Out:
# LinearRegression()

# %%
#help(lm)
#coef_, intercept_

# %%
print(lm.coef_, lm.intercept_)
# Out:
# [[0.05454575]] [6.9486832]

# %%
y_train_pred = lm.predict(X_train_lm)
y_test_pred = lm.predict(X_test.values.reshape(-1,1))

# %%
print(mean_squared_error(y_train, y_train_pred))
print(mean_squared_error(y_test, y_test_pred))
# Out:
# 5.752400386486837
# 4.07755637182695

# %%
print(r2_score(y_train, y_train_pred))
print(r2_score(y_test, y_test_pred))
# Out:
# 0.8157933136480388
# 0.792103160124566
